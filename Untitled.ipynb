# %%
import os
import xarray as xr

indir='c:Users\sa01ld\m_moorproc_toolbox\data\moor\THREDDS'
file='Rockall-Trough-Mooring-Time-Series-2022.nc'
fpath=os.path.join(indir,file)
fpath
# Out:
# 'c:Users\\sa01ld\\m_moorproc_toolbox\\data\\moor\\THREDDS\\Rockall-Trough-Mooring-Time-Series-2022.nc'

# %%
ds=xr.open_dataset('data\\moor\\THREDDS\\Rockall-Trough-Mooring-Time-Series-2022.nc')
# ds.SG_EAST.isel(PRES=slice(None, 10)).plot(x='TIME',aspect=2, size=10)
ds.SG_EAST.isel().plot(x='TIME',aspect=2, size=10)

# %%
ds.SG_EAST.plot(x='TIME',aspect=2, size=10)

# %%
ds=xr.open_dataset('Rockall-Trough-Mooring-Time-Series-2020.nc')
ds.SG_EAST.isel(PRES=slice(None, 10)).plot(x='TIME',aspect=2, size=10)
