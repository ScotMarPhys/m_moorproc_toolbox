# %%
import xarray as xr

# %%
nor='C:\\Users\\sa01ld\\m_moorproc_toolbox\\exec\\gitrepo\\export_Oceansites\\oceansites_format\\rteb1_06_2020_Nortek.nc'
mct='C:\\Users\\sa01ld\\m_moorproc_toolbox\\exec\\gitrepo\\export_Oceansites\\oceansites_format\\rteb1_06_2020_MCAT.nc'
ds1=xr.open_dataset(nor)
ds2=xr.open_dataset(mct)

# %%
ds1
# Out:
# <xarray.Dataset>
# Dimensions:    (TIME: 15374, LATITUDE: 1, LONGITUDE: 1, DEPTH: 5)
# Coordinates:
#   * TIME       (TIME) datetime64[ns] 2020-10-12T21:00:00.000442624 ... 2022-0...
#   * LATITUDE   (LATITUDE) float32 57.1
#   * LONGITUDE  (LONGITUDE) float32 -9.559
#   * DEPTH      (DEPTH) float32 102.0 244.0 494.0 996.0 1.349e+03
# Data variables:
#     PRES       (TIME, DEPTH) float32 ...
#     VCUR       (TIME, DEPTH) float32 ...
#     UCUR       (TIME, DEPTH) float32 ...
#     WCUR       (TIME, DEPTH) float32 ...
# Attributes: (12/53)
#     site_code:                     OSNAP
#     platform_code:                 OSNAP-rteb1_06_2020
#     data_mode:                     D
#     title:                         OSNAP CM Data 10/2020-07/2022
#     summary:                       sea water velocity at nominal depth 102   ...
#     naming_authority:              OceanSITES
#     ...                            ...
# ...

# %%
ds2
# Out:
# <xarray.Dataset>
# Dimensions:    (TIME: 30749, LATITUDE: 1, LONGITUDE: 1, DEPTH: 12)
# Coordinates:
#   * TIME       (TIME) datetime64[ns] 2020-10-12T20:00:01.008004352 ... 2022-0...
#   * LATITUDE   (LATITUDE) float32 57.1
#   * LONGITUDE  (LONGITUDE) float32 -9.559
#   * DEPTH      (DEPTH) float32 52.0 103.0 250.0 ... 1.497e+03 1.65e+03 1.762e+03
# Data variables:
#     PRES       (TIME, DEPTH) float32 ...
#     TEMP       (TIME, DEPTH) float32 ...
#     PSAL       (TIME, DEPTH) float32 ...
#     CNDC       (TIME, DEPTH) float32 ...
# Attributes: (12/53)
#     site_code:                     OSNAP
#     platform_code:                 OSNAP-rteb1_06_2020
#     data_mode:                     D
#     title:                         OSNAP MCTD Data 10/2020-07/2022
#     summary:                       Water temperature and salinity at nominal ...
#     naming_authority:              OceanSITES
#     ...                            ...
# ...

# %%
ds=xr.merge([ds1,ds2])

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (TIME: 46123, LATITUDE: 1, LONGITUDE: 1, DEPTH: 17)
# Coordinates:
#   * TIME       (TIME) datetime64[ns] 2020-10-12T20:00:01.008004352 ... 2022-0...
#   * LATITUDE   (LATITUDE) float32 57.1
#   * LONGITUDE  (LONGITUDE) float32 -9.559
#   * DEPTH      (DEPTH) float32 52.0 102.0 103.0 ... 1.497e+03 1.65e+03 1.762e+03
# Data variables:
#     PRES       (TIME, DEPTH) float32 56.4 nan 105.3 ... 1.673e+03 1.79e+03
#     VCUR       (TIME, DEPTH) float32 nan nan nan nan nan ... nan nan nan nan nan
#     UCUR       (TIME, DEPTH) float32 nan nan nan nan nan ... nan nan nan nan nan
#     WCUR       (TIME, DEPTH) float32 nan nan nan nan nan ... nan nan nan nan nan
#     TEMP       (TIME, DEPTH) float32 12.5 nan 10.55 nan ... 4.161 3.785 3.701
#     PSAL       (TIME, DEPTH) float32 35.27 nan 35.37 nan ... 34.96 34.93 34.93
#     CNDC       (TIME, DEPTH) float32 40.79 nan 39.03 nan ... 33.33 33.04 33.01
# Attributes: (12/53)
# ...

# %%
ds.PRES.plot.line(x='TIME')
