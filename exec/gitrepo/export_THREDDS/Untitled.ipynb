# %%
import xarray as xr

# %%
ds=xr.open_dataset('p5450075.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                                                   (
#                                                                sg_data_point: 304,
#                                                                magnetometer_data_point: 304,
#                                                                gc_event: 21,
#                                                                gc_state: 10,
#                                                                gps_info: 3,
#                                                                trajectory: 1)
# Coordinates:
#     ctd_time                                                  (sg_data_point) datetime64[ns] ...
#     ctd_depth                                                 (sg_data_point) float64 ...
#     latitude                                                  (sg_data_point) float64 ...
#     longitude                                                 (sg_data_point) float64 ...
# ...
